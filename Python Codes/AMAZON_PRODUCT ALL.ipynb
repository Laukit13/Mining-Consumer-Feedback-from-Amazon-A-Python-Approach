# %%
import pandas as pd
df_NON_ECO = pd.concat(
    map(pd.read_csv,['NON_ECO_Friendly_1.csv', 'NON_ECO_Friendly_2.csv','NON_ECO_Friendly_3.csv','NON_ECO_Friendly_4.csv','NON_ECO_Friendly_5.csv','NON_ECO_Friendly_6.csv','NON_ECO_Friendly_7.csv','NON_ECO_Friendly_8.csv','NON_ECO_Friendly_9.csv','NON_ECO_Friendly_10.csv','NON_ECO_Friendly_11.csv']), ignore_index=True)
print(df_NON_ECO)
# Out:
#        Unnamed: 0             Names  \
# 0               0     Kimberly Luna
# 1               1       Barrett Ray
# 2               2     kristi kramer
# 3               3      Richard Seal
# 4               4  LePonda Bradshaw
# ...           ...               ...
# 18875        1005          Ron Hill
# 18876        1006   Amazon Customer
# 18877        1007           firefly
# 18878        1008     Andrew Perrie
# 18879        1009              Sara
#
#                                     Review_Title  \
# 0        A little flimsy but good for the price.
# 1                 Knives should be a bit thicker
# 2                               Not very durable
# 3                                  Not very good
# 4                              Very thin plastic
# ...                                          ...
# 18875  Never get clogged, even chunks of banana.
# 18876                              Great product
# 18877                                   to short
# ...

# %%
df_ECO=pd.concat(
    map(pd.read_csv,['ECO_Friendly_1.csv', 'ECO_Friendly_2.csv','ECO_Friendly_3.csv','ECO_Friendly_4.csv','ECO_Friendly_5.csv','ECO_Friendly_6.csv','ECO_Friendly_7.csv','ECO_Friendly_8.csv','ECO_Friendly_9.csv','ECO_Friendly_10.csv','ECO_Friendly_11.csv']), ignore_index=True)
print(df_ECO)
# Out:
#        Unnamed: 0            Names              Review_Title  \
# 0               0            NormB              Good Quality
# 1               1         FergsDCF                  Love 'em
# 2               2          poi dog    Love these dishcloths!
# 3               3           SarahW  Great Swedish dishcloths
# 4               4   Very satisfied            Very satisfied
# ...           ...              ...                       ...
# 22165        2225  Cypress Galiano                   Garbage
# 22166        2226  Client d'Amazon                   quality
# 22167        2227      John Clarke             As advertised
# 22168        2228            josee                 Tumbs up!
# 22169        2229   Gupta Fine Art    Meh, you can do better
#
#                                                   Review             Ratings  \
# 0      Pro: These are thick enough to do normal kitch...  5.0 out of 5 stars
# ...

# %%
df_NON_ECO.head()
# Out:
#    Unnamed: 0             Names                             Review_Title  \
# 0           0     Kimberly Luna  A little flimsy but good for the price.
# 1           1       Barrett Ray           Knives should be a bit thicker
# 2           2     kristi kramer                         Not very durable
# 3           3      Richard Seal                            Not very good
# 4           4  LePonda Bradshaw                        Very thin plastic
#
#                                               Review             Ratings  \
# 0  Product is good for what you pay. Utensils wil...  4.0 out of 5 stars
# 1  The spoons and forks were very nice, but knive...  4.0 out of 5 stars
# 2                               Value but not sturdy  4.0 out of 5 stars
# 3  They're small and pretty flimsy. If it's bough...  3.0 out of 5 stars
# 4  These are flimsy and not like the kind I norma...  4.0 out of 5 stars
#
#                                         Review_Dates    Uploaded_Images  \
# ...

# %%
df_ECO.head()
# Out:
#    Unnamed: 0           Names              Review_Title  \
# 0           0           NormB              Good Quality
# 1           1        FergsDCF                  Love 'em
# 2           2         poi dog    Love these dishcloths!
# 3           3          SarahW  Great Swedish dishcloths
# 4           4  Very satisfied            Very satisfied
#
#                                               Review             Ratings  \
# 0  Pro: These are thick enough to do normal kitch...  5.0 out of 5 stars
# 1  I bought my first pack over a year ago, and th...  5.0 out of 5 stars
# 2  This is the third time I've ordered these dish...  5.0 out of 5 stars
# 3  I just got these in, trying to be more eco con...  5.0 out of 5 stars
# 4  These washcloths dry quickly and do not smell....  5.0 out of 5 stars
#
#                                         Review_Dates    Uploaded_Images  \
# 0  Reviewed in the United States on December 2, 2022  Image Not Present
# ...

# %%
df_NON_ECO.shape
# Out:
# (18880, 8)

# %%
df_ECO.shape
# Out:
# (22170, 8)

# %%
df_ECO.drop('Unnamed: 0',axis='columns',inplace=True)
df_NON_ECO.drop('Unnamed: 0',axis='columns',inplace=True)

# %%
df_ECO.head()
# Out:
#          Names                      Review_Title  \
# 0     Jennifer  The words didn’t translate well.
# 1   rostrofsky                   Cars and trucks
# 2  Sarah Moore                              Cute
# 3    Lady Kerr             Really small but cute
# 4         Lolo                          Worth it
#
#                                               Review             Ratings  \
# 0  The trucks are very cute, they work well and s...  4.0 out of 5 stars
# 1  Great grandson loved them they also shoot acro...  5.0 out of 5 stars
# 2  These are gifts and I think the little foster ...  5.0 out of 5 stars
# 3  I thought they were bigger they are retractabl...  4.0 out of 5 stars
# 4  I was christmas and my nephew needed a gift si...  5.0 out of 5 stars
#
#                                         Review_Dates    Uploaded_Images  \
# 0  Reviewed in the United States 🇺🇸 on October 25...  Image Not Present
# 1  Reviewed in the United States 🇺🇸 on November 5...  Image Not Present
# ...

# %%
df_NON_ECO.head()
# Out:
#               Names                             Review_Title  \
# 0     Kimberly Luna  A little flimsy but good for the price.
# 1       Barrett Ray           Knives should be a bit thicker
# 2     kristi kramer                         Not very durable
# 3      Richard Seal                            Not very good
# 4  LePonda Bradshaw                        Very thin plastic
#
#                                               Review             Ratings  \
# 0  Product is good for what you pay. Utensils wil...  4.0 out of 5 stars
# 1  The spoons and forks were very nice, but knive...  4.0 out of 5 stars
# 2                               Value but not sturdy  4.0 out of 5 stars
# 3  They're small and pretty flimsy. If it's bough...  3.0 out of 5 stars
# 4  These are flimsy and not like the kind I norma...  4.0 out of 5 stars
#
#                                         Review_Dates    Uploaded_Images  \
# 0  Reviewed in the United States on November 2, 2022  Image Not Present
# ...

# %%
df_ECO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Names            22168 non-null  object
#  1   Review_Title     22163 non-null  object
#  2   Review           22146 non-null  object
#  3   Ratings          22170 non-null  object
#  4   Review_Dates     22170 non-null  object
#  5   Uploaded_Images  22170 non-null  object
#  6   Helpful          22170 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.2+ MB

# %%
df_NON_ECO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18880 entries, 0 to 18879
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Names            18876 non-null  object
#  1   Review_Title     18875 non-null  object
#  2   Review           18838 non-null  object
#  3   Ratings          18880 non-null  object
#  4   Review_Dates     18880 non-null  object
#  5   Uploaded_Images  18880 non-null  object
#  6   Helpful          18880 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
df_NON_ECO.to_csv('NON_ECO_FRIENDLY_PRD_REV.csv')
df_ECO.to_csv('ECO_FRIENDLY_PRD_REV.csv')

# %%
# import pandas as pd
# df1 = pd.read_csv("NON_ECO_Friendly_1.csv")
# df2 = pd.read_csv("NON_ECO_Friendly_2.csv")
# df3 = pd.read_csv("NON_ECO_Friendly_3.csv")
# df4 = pd.read_csv("NON_ECO_Friendly_4.csv")
# df5 = pd.read_csv("NON_ECO_Friendly_5.csv")
# df6 = pd.read_csv("NON_ECO_Friendly_6.csv")
# df7 = pd.read_csv("NON_ECO_Friendly_7.csv")
# df8 = pd.read_csv("NON_ECO_Friendly_8.csv")
# df9 = pd.read_csv("NON_ECO_Friendly_9.csv")
# df10= pd.read_csv("NON_ECO_Friendly_10.csv")
# df11= pd.read_csv("NON_ECO_Friendly_11.csv")

# print(df1.shape)
# print(df2.shape)
# print(df3.shape)
# print(df4.shape)
# print(df5.shape)
# print(df6.shape)
# print(df7.shape)
# print(df8.shape)
# print(df9.shape)
# print(df10.shape)
# print(df11.shape)
# Out:
# (1810, 8)
# (1170, 8)
# (2600, 8)
# (2670, 8)
# (2300, 8)
# (1600, 8)
# (1700, 8)
# (1000, 8)
# (2000, 8)
# (1020, 8)
# (1010, 8)

# %%
# 1810+1170+2600+2670+2300+1600+1700+1000+2000+1020+1010
# Out:
# 18880

# %%
# import pandas as pd
# df1 = pd.read_csv("ECO_Friendly_1.csv")
# df2 = pd.read_csv("ECO_Friendly_2.csv")
# df3 = pd.read_csv("ECO_Friendly_3.csv")
# df4 = pd.read_csv("ECO_Friendly_4.csv")
# df5 = pd.read_csv("ECO_Friendly_5.csv")
# df6 = pd.read_csv("ECO_Friendly_6.csv")
# df7 = pd.read_csv("ECO_Friendly_7.csv")
# df8 = pd.read_csv("ECO_Friendly_8.csv")
# df9 = pd.read_csv("ECO_Friendly_9.csv")
# df10= pd.read_csv("ECO_Friendly_10.csv")
# df11= pd.read_csv("ECO_Friendly_11.csv")

# print(df1.shape)
# print(df2.shape)
# print(df3.shape)
# print(df4.shape)
# print(df5.shape)
# print(df6.shape)
# print(df7.shape)
# print(df8.shape)
# print(df9.shape)
# print(df10.shape)
# print(df11.shape)
# Out:
# (2000, 8)
# (2030, 8)
# (1410, 8)
# (1420, 8)
# (1240, 8)
# (1860, 8)
# (1600, 8)
# (3080, 8)
# (2220, 8)
# (3080, 8)
# (2230, 8)

# %%
# 2000+2030+1410+1420+1240+1860+1600+3080+2220+3080+2230
# Out:
# 22170

# %%
import pandas as pd
df_ALL = pd.concat(
    map(pd.read_csv,['NON_ECO_FRIENDLY_PRD_REV.csv','ECO_FRIENDLY_PRD_REV.csv']), ignore_index=True)
print(df_ALL)
# Out:
#        Unnamed: 0             Names                             Review_Title  \
# 0               0     Kimberly Luna  A little flimsy but good for the price.
# 1               1       Barrett Ray           Knives should be a bit thicker
# 2               2     kristi kramer                         Not very durable
# 3               3      Richard Seal                            Not very good
# 4               4  LePonda Bradshaw                        Very thin plastic
# ...           ...               ...                                      ...
# 41045       22165   Cypress Galiano                                  Garbage
# 41046       22166   Client d'Amazon                                  quality
# 41047       22167       John Clarke                            As advertised
# 41048       22168             josee                                Tumbs up!
# 41049       22169    Gupta Fine Art                   Meh, you can do better
#
# ...

# %%
df_ALL.to_csv('ALL_AMZN_PRD_REV.csv')
